# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# Source: https://www.kaggle.com/rupeshraundal/marketcheck-automotive-data-us-canada
#
# Context
# MarketCheck's automotive data covers 8 years of inventory across the US and Canada. Each day our systems crawl and aggregate inventory from over 65k dealer websites to deliver the most comprehensive and up-to-date depictions of market activity available anywhere.
#
# Individual listing records show year, make, model and trim, with VIN-level histories, showing the most recent time the car showed up online back to the earliest, with every change that occurred over that time.
#
# Equipment breakdowns give fuel type, engine size, transmission, color, driveline and body style with links back to the VDP of the source we obtained the information from. The complete data dictionary can be found here - https://storage.googleapis.com/marketcheck-sample-feeds/cars_data_dictionary.xlsx
# In addition to our car inventory data, Marketcheck also provide several other powerful APIs for CRM marketing scrubs, basic VIN decoding, OEM build data, recalls, dealer profiles, and market activity. Visit us for more details at www.marketcheck.com
#
# Join the discussion at Marketcheck forum

# %%
csv_file = "Resources/used_cars.zip"
used_cars = pd.read_csv(csv_file)
used_cars.head()
# Out:
#               id                vin    price    miles stock_no    year  \
# 0  28ee2068-66bb  ZFFRG43A5R0098567      NaN  13342.0   B1255C  1994.0
# 1  d22d842c-ee2a  1B3BR65EXRV100761  41898.0  21208.0  P32613A  1994.0
# 2  362f0565-89fd  JNKNG01D3RM263526      NaN      NaN     1276  1994.0
# 3  96fb40cf-fc22  1B3BR65EXRV100761  41898.0  21208.0  P32613A  1994.0
# 4  5701918a-4d82  1B3BR65EXRV100761  41895.0  21208.0  P32613A  1994.0
#
#        make  model    trim    body_type vehicle_type drivetrain transmission  \
# 0   Ferrari    348  Spider  Convertible          NaN        NaN          NaN
# 1     Dodge  Viper   RT/10  Convertible          Car        RWD       Manual
# 2  INFINITI    Q45    Base        Sedan          Car        RWD    Automatic
# 3     Dodge  Viper   RT/10  Convertible          Car        RWD       Manual
# 4     Dodge  Viper   RT/10  Convertible          Car        RWD       Manual
#
#   fuel_type  engine_size engine_block        city state
# 0       NaN          3.4            V     Chicago    IL
# 1  Unleaded          8.0            V      Newark    OH
# 2  Unleaded          4.5            V     Decatur    GA
# 3  Unleaded          8.0            V  Marysville    OH
# 4  Unleaded          8.0            V       Heath    OH

# %%
used_cars = used_cars.drop(['id', 'vin', 'stock_no', 'city', 'state'], axis = 1)
used_cars
# Out:
#            price    miles    year      make  model    trim    body_type  \
# 0            NaN  13342.0  1994.0   Ferrari    348  Spider  Convertible
# 1        41898.0  21208.0  1994.0     Dodge  Viper   RT/10  Convertible
# 2            NaN      NaN  1994.0  INFINITI    Q45    Base        Sedan
# 3        41898.0  21208.0  1994.0     Dodge  Viper   RT/10  Convertible
# 4        41895.0  21208.0  1994.0     Dodge  Viper   RT/10  Convertible
# ...          ...      ...     ...       ...    ...     ...          ...
# 1048570      NaN      NaN     NaN       NaN    NaN     NaN          NaN
# 1048571      NaN      NaN     NaN       NaN    NaN     NaN          NaN
# 1048572      NaN      NaN     NaN       NaN    NaN     NaN          NaN
# 1048573      NaN      NaN     NaN       NaN    NaN     NaN          NaN
# 1048574      NaN      NaN     NaN       NaN    NaN     NaN          NaN
#
#         vehicle_type drivetrain transmission fuel_type  engine_size  \
# 0                NaN        NaN          NaN       NaN          3.4
# 1                Car        RWD       Manual  Unleaded          8.0
# 2                Car        RWD    Automatic  Unleaded          4.5
# 3                Car        RWD       Manual  Unleaded          8.0
# 4                Car        RWD       Manual  Unleaded          8.0
# ...              ...        ...          ...       ...          ...
# 1048570          NaN        NaN          NaN       NaN          NaN
# 1048571          NaN        NaN          NaN       NaN          NaN
# 1048572          NaN        NaN          NaN       NaN          NaN
# 1048573          NaN        NaN          NaN       NaN          NaN
# 1048574          NaN        NaN          NaN       NaN          NaN
#
#         engine_block
# 0                  V
# 1                  V
# 2                  V
# 3                  V
# 4                  V
# ...              ...
# 1048570          NaN
# 1048571          NaN
# 1048572          NaN
# 1048573          NaN
# 1048574          NaN
#
# [1048575 rows x 13 columns]

# %%
used_cars.dropna()
# Out:
#            price    miles    year   make     model     trim    body_type  \
# 1        41898.0  21208.0  1994.0  Dodge     Viper    RT/10  Convertible
# 3        41898.0  21208.0  1994.0  Dodge     Viper    RT/10  Convertible
# 4        41895.0  21208.0  1994.0  Dodge     Viper    RT/10  Convertible
# 5        94995.0     29.0  1994.0  Dodge     Viper       RT  Convertible
# 10       29900.0   7900.0  1994.0  Dodge     Viper    RT/10  Convertible
# ...          ...      ...     ...    ...       ...      ...          ...
# 1046859  29230.0      0.0  2022.0    Kia  Sportage       EX          SUV
# 1046860  35175.0      5.0  2022.0    Kia  Sportage       EX          SUV
# 1046861  35175.0      5.0  2022.0    Kia  Sportage       EX          SUV
# 1046863  37785.0      5.0  2022.0    Kia   Stinger  GT-Line    Hatchback
# 1046865  40070.0      0.0  2022.0    Kia   Stinger  GT-Line    Hatchback
#
#         vehicle_type drivetrain transmission         fuel_type  engine_size  \
# 1                Car        RWD       Manual          Unleaded          8.0
# 3                Car        RWD       Manual          Unleaded          8.0
# 4                Car        RWD       Manual          Unleaded          8.0
# 5                Car        RWD       Manual          Unleaded          8.0
# 10               Car        RWD       Manual          Unleaded          8.0
# ...              ...        ...          ...               ...          ...
# 1046859        Truck        FWD    Automatic          Unleaded          2.4
# 1046860        Truck        4WD    Automatic          Unleaded          2.4
# 1046861        Truck        4WD    Automatic          Unleaded          2.4
# 1046863          Car        RWD    Automatic  Premium Unleaded          2.5
# 1046865          Car        4WD    Automatic  Premium Unleaded          2.5
#
#         engine_block
# 1                  V
# 3                  V
# 4                  V
# 5                  V
# 10                 V
# ...              ...
# 1046859            I
# 1046860            I
# 1046861            I
# 1046863            I
# 1046865            I
#
# [926514 rows x 13 columns]

# %%
used_cars.drop_duplicates()
# Out:
#            price    miles    year        make      model                trim  \
# 0            NaN  13342.0  1994.0     Ferrari        348              Spider
# 1        41898.0  21208.0  1994.0       Dodge      Viper               RT/10
# 2            NaN      NaN  1994.0    INFINITI        Q45                Base
# 4        41895.0  21208.0  1994.0       Dodge      Viper               RT/10
# 5        94995.0     29.0  1994.0       Dodge      Viper                  RT
# ...          ...      ...     ...         ...        ...                 ...
# 1046862      NaN      4.0  2022.0  Mitsubishi  Outlander  SEL Launch Edition
# 1046863  37785.0      5.0  2022.0         Kia    Stinger             GT-Line
# 1046864      NaN      NaN  2022.0  Mitsubishi  Outlander  SEL Launch Edition
# 1046865  40070.0      0.0  2022.0         Kia    Stinger             GT-Line
# 1046866      NaN      NaN     NaN         NaN        NaN                 NaN
#
#            body_type vehicle_type drivetrain transmission         fuel_type  \
# 0        Convertible          NaN        NaN          NaN               NaN
# 1        Convertible          Car        RWD       Manual          Unleaded
# 2              Sedan          Car        RWD    Automatic          Unleaded
# 4        Convertible          Car        RWD       Manual          Unleaded
# 5        Convertible          Car        RWD       Manual          Unleaded
# ...              ...          ...        ...          ...               ...
# 1046862          SUV        Truck        4WD    Automatic          Unleaded
# 1046863    Hatchback          Car        RWD    Automatic  Premium Unleaded
# 1046864          SUV        Truck        4WD    Automatic          Unleaded
# 1046865    Hatchback          Car        4WD    Automatic  Premium Unleaded
# 1046866          NaN          NaN        NaN          NaN               NaN
#
#          engine_size engine_block
# 0                3.4            V
# 1                8.0            V
# 2                4.5            V
# 4                8.0            V
# 5                8.0            V
# ...              ...          ...
# 1046862          2.5            I
# 1046863          2.5            I
# 1046864          2.5            I
# 1046865          2.5            I
# 1046866          NaN          NaN
#
# [622438 rows x 13 columns]

# %%
# Out:
#            price    miles    year   make     model     trim    body_type  \
# 1        41898.0  21208.0  1994.0  Dodge     Viper    RT/10  Convertible
# 3        41898.0  21208.0  1994.0  Dodge     Viper    RT/10  Convertible
# 4        41895.0  21208.0  1994.0  Dodge     Viper    RT/10  Convertible
# 5        94995.0     29.0  1994.0  Dodge     Viper       RT  Convertible
# 10       29900.0   7900.0  1994.0  Dodge     Viper    RT/10  Convertible
# ...          ...      ...     ...    ...       ...      ...          ...
# 1046859  29230.0      0.0  2022.0    Kia  Sportage       EX          SUV
# 1046860  35175.0      5.0  2022.0    Kia  Sportage       EX          SUV
# 1046861  35175.0      5.0  2022.0    Kia  Sportage       EX          SUV
# 1046863  37785.0      5.0  2022.0    Kia   Stinger  GT-Line    Hatchback
# 1046865  40070.0      0.0  2022.0    Kia   Stinger  GT-Line    Hatchback
#
#         vehicle_type drivetrain transmission         fuel_type  engine_size  \
# 1                Car        RWD       Manual          Unleaded          8.0
# 3                Car        RWD       Manual          Unleaded          8.0
# 4                Car        RWD       Manual          Unleaded          8.0
# 5                Car        RWD       Manual          Unleaded          8.0
# 10               Car        RWD       Manual          Unleaded          8.0
# ...              ...        ...          ...               ...          ...
# 1046859        Truck        FWD    Automatic          Unleaded          2.4
# 1046860        Truck        4WD    Automatic          Unleaded          2.4
# 1046861        Truck        4WD    Automatic          Unleaded          2.4
# 1046863          Car        RWD    Automatic  Premium Unleaded          2.5
# 1046865          Car        4WD    Automatic  Premium Unleaded          2.5
#
#         engine_block
# 1                  V
# 3                  V
# 4                  V
# 5                  V
# 10                 V
# ...              ...
# 1046859            I
# 1046860            I
# 1046861            I
# 1046863            I
# 1046865            I
#
# [926514 rows x 13 columns]

# %%
csv_file2 = "Resources/real-world-fuel-efficiency-1.csv"
fuel_economy_ny = pd.read_csv(csv_file2)
fuel_economy_ny.head()
# Out:
#    YEAR       MAKE      MODEL Hybrid/Non-Hybrid STANDARD TYPE  \
# 0  2008      HONDA   CIVIC GX        Non-Hybrid         SEDAN
# 1  2008       FORD  CROWN VIC        Non-Hybrid         SEDAN
# 2  2008  CHEVROLET    EXPRESS        Non-Hybrid           VAN
# 3  2008       FORD      FOCUS        Non-Hybrid         SEDAN
# 4  2008       FORD     FUSION        Non-Hybrid         SEDAN
#
#    EPA RATING (CITY)  Vehicle Count  TOTAL ACTUAL MILES  TOTAL ACTUAL FUEL  \
# 0                 24              9                4459              221.0
# 1                 11              7               17162             1771.0
# 2                 13              1                 413               65.0
# 3                 24             49               13074              793.0
# 4                 18              5               29482             1813.0
#
#    EPA EXPECTED FUEL  ACTUAL FUEL ECONOMY Geotab  \
# 0             185.79                       20.18
# 1            1560.18                        9.69
# 2              31.77                        6.35
# 3             544.75                       16.49
# 4            1637.89                       16.26
#
#    PERCENT % DIFFERENCE ACTUAL TO EPA ESTIMATED FUEL COSTS PER GALLON  \
# 0                               -0.16                        $552.50
# 1                               -0.12                      $4,427.50
# 2                               -0.51                        $162.50
# 3                               -0.31                      $1,982.50
# 4                               -0.10                      $4,532.50
#
#   FUEL COSTS PER MILE
# 0              $0.12
# 1              $0.26
# 2              $0.39
# 3              $0.15
# 4              $0.15

# %%
fuel_economy_ny = fuel_economy_ny.drop('Vehicle Count', 1)
fuel_economy_ny
# Out:
# C:\Users\mandi\AppData\Local\Temp/ipykernel_11640/1540716452.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   fuel_economy_ny = fuel_economy_ny.drop('Vehicle Count', 1)
#      YEAR          MAKE          MODEL Hybrid/Non-Hybrid STANDARD TYPE  \
# 0    2008         HONDA       CIVIC GX        Non-Hybrid         SEDAN
# 1    2008          FORD      CROWN VIC        Non-Hybrid         SEDAN
# 2    2008     CHEVROLET        EXPRESS        Non-Hybrid           VAN
# 3    2008          FORD          FOCUS        Non-Hybrid         SEDAN
# 4    2008          FORD         FUSION        Non-Hybrid         SEDAN
# ..    ...           ...            ...               ...           ...
# 101  2019     CHEVROLET        EXPRESS        Non-Hybrid           VAN
# 102  2019          FORD           F150        Non-Hybrid        PICKUP
# 103  2019          FORD           F250        Non-Hybrid        PICKUP
# 104  2019  FREIGHTLINER  SPRINTER 3500        Non-Hybrid           VAN
# 105  2019          FORD    TRANSIT VAN        Non-Hybrid           VAN
#
#      EPA RATING (CITY)  TOTAL ACTUAL MILES  TOTAL ACTUAL FUEL  \
# 0                   24                4459              221.0
# 1                   11               17162             1771.0
# 2                   13                 413               65.0
# 3                   24               13074              793.0
# 4                   18               29482             1813.0
# ..                 ...                 ...                ...
# 101                 13               10316              885.0
# 102                 16               56410             5419.0
# 103                 12               84521             5449.0
# 104                 15                3277              296.0
# 105                 20               29068             2331.0
#
#      EPA EXPECTED FUEL  ACTUAL FUEL ECONOMY Geotab  \
# 0               185.79                       20.18
# 1              1560.18                        9.69
# 2                31.77                        6.35
# 3               544.75                       16.49
# 4              1637.89                       16.26
# ..                 ...                         ...
# 101             793.54                       11.66
# 102            3525.63                       10.41
# 103            7043.42                       15.51
# 104             218.47                       11.07
# 105            1453.40                       12.47
#
#      PERCENT % DIFFERENCE ACTUAL TO EPA ESTIMATED FUEL COSTS PER GALLON  \
# 0                                 -0.16                        $552.50
# 1                                 -0.12                      $4,427.50
# 2                                 -0.51                        $162.50
# 3                                 -0.31                      $1,982.50
# 4                                 -0.10                      $4,532.50
# ..                                  ...                             ...
# 101                               -0.10                      $2,212.50
# 102                               -0.35                     $13,547.50
# 103                                0.29                     $13,622.50
# 104                               -0.26                        $740.00
# 105                               -0.38                      $5,827.50
#
#     FUEL COSTS PER MILE
# 0                $0.12
# 1                $0.26
# 2                $0.39
# 3                $0.15
# 4                $0.15
# ..                  ...
# 101              $0.21
# 102              $0.24
# 103              $0.16
# 104              $0.23
# 105              $0.20
#
# [106 rows x 13 columns]

# %%
from password import password

# %%
from sqlalchemy import create_engine
engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/CarSQL_DB')
connection = engine.connect()

# %%
 engine.table_names()
# Out:
# C:\Users\mandi\AppData\Local\Temp/ipykernel_11640/1612904836.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# []

# %%
fuel_economy_ny.to_sql(name='fuel_efficiency', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from fuel_efficiency', con=engine).head()
# Out:
#    YEAR       MAKE      MODEL Hybrid/Non-Hybrid STANDARD TYPE  \
# 0  2008      HONDA   CIVIC GX        Non-Hybrid         SEDAN
# 1  2008       FORD  CROWN VIC        Non-Hybrid         SEDAN
# 2  2008  CHEVROLET    EXPRESS        Non-Hybrid           VAN
# 3  2008       FORD      FOCUS        Non-Hybrid         SEDAN
# 4  2008       FORD     FUSION        Non-Hybrid         SEDAN
#
#    EPA RATING (CITY)  TOTAL ACTUAL MILES  TOTAL ACTUAL FUEL  \
# 0                 24                4459              221.0
# 1                 11               17162             1771.0
# 2                 13                 413               65.0
# 3                 24               13074              793.0
# 4                 18               29482             1813.0
#
#    EPA EXPECTED FUEL  ACTUAL FUEL ECONOMY Geotab  \
# 0             185.79                       20.18
# 1            1560.18                        9.69
# 2              31.77                        6.35
# 3             544.75                       16.49
# 4            1637.89                       16.26
#
#    PERCENT % DIFFERENCE ACTUAL TO EPA ESTIMATED FUEL COSTS PER GALLON  \
# 0                               -0.16                        $552.50
# 1                               -0.12                      $4,427.50
# 2                               -0.51                        $162.50
# 3                               -0.31                      $1,982.50
# 4                               -0.10                      $4,532.50
#
#   FUEL COSTS PER MILE
# 0              $0.12
# 1              $0.26
# 2              $0.39
# 3              $0.15
# 4              $0.15
